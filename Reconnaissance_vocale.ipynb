# %% [markdown]
# Lab: Speech Recognition
# Name: Khedidja Rahmani
# Module: Natural Language Processing (NLP)
#
# Objective:
# The objective of this lab is to convert an audio file containing spoken language into written text using a speech recognition module in Python.

# %%
# !pip install SpeechRecognition pydub nltk

# %%
import speech_recognition as sr
import nltk
from nltk.tokenize import word_tokenize
import soundfile as sf
import numpy as np

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8685b5fe-6f82-410f-b7a7-4870b23514b5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8685b5fe-6f82-410f-b7a7-4870b23514b5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'audio_fr.wav.m4a',
#  'audio_fr.wav',
#  'audio_fr.wav (1).m4a',
#  'sample_data']

# %%
import os
print("Dossier courant :", os.getcwd())
print("Fichiers :", os.listdir())
# Out:
# Dossier courant : /content
# Fichiers : ['.config', 'audio_fr.wav.m4a', 'audio_fr.wav', 'audio_fr.wav (1).m4a', 'sample_data']

# %%
# !apt-get install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 1 not upgraded.

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'audio_fr.wav.m4a',
#  'audio_fr.wav',
#  'audio_fr.wav (1).m4a',
#  'sample_data']

# %%
# !apt-get install ffmpeg -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 1 not upgraded.

# %%
# !ffmpeg -i audio_fr.wav.m4a audio_fr.wav
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'audio_fr.wav.m4a',
#  'audio_fr.wav',
#  'audio_fr.wav (1).m4a',
#  'sample_data']

# %%
import speech_recognition as sr

recognizer = sr.Recognizer()

with sr.AudioFile("/content/audio_fr.wav") as source:
    audio = recognizer.record(source)

texte_reconnu = recognizer.recognize_google(audio, language="fr-FR")
print("Texte reconnu :", texte_reconnu)
# Out:
# Texte reconnu : salut je suis étudiante en informatique
